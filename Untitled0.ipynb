# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishSinghJadoun/image_classifier/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !unrar x /content/drive/MyDrive/dataset.rar /content/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/dataset.rar
#
# Creating    /content/dataset                                          OK
# Creating    /content/dataset/images                                   OK
# Creating    /content/dataset/images/train                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17129, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17129 (delta 32), reused 10 (delta 10), pack-reused 17080 (from 4)
# Receiving objects: 100% (17129/17129), 15.84 MiB | 10.91 MiB/s, done.
# Resolving deltas: 100% (11744/11744), done.

# %%
# %cd yolov5
#   37d5dcd064d8e5c665939708468d1de7108032f7  api key
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# !pip install wandb
import wandb
wandb.login()
wandb.init(project="pcb_advanced") # pcb_detection
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jadon185 (jadon185-indian-institute-of-technology-kanpur). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/yolov5/wandb/run-20250115_113941-advgryus</code>
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 200 --data dataset.yaml --weights yolov5s.pt --cache --name pcb_1st
# Out:
# Streaming output truncated to the last 5000 lines.
#      73/199      1.81G    0.03208     0.0618    0.02287        138        416:  57% 21/37 [00:05<00:04,  3.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      73/199      1.81G    0.03206    0.06184    0.02288        129        416:  59% 22/37 [00:05<00:04,  3.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      73/199      1.81G    0.03203    0.06136    0.02304        100        416:  62% 23/37 [00:05<00:03,  3.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
files.download('/content/yolov5/runs/train/pcb_1st/weights/best.pt')
# files.download('/content/yolov5/runs/train/pcb_1st/weights/last.pt')-
# files.download('/content/yolov5/dataset.yaml')
files.download('/content/yolov5/runs/train/pcb_1st/hyp.yaml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-53a158646965> in <cell line: 1>()
# ----> 1 files.download('/content/yolov5/runs/train/pcb_1st/weights/best.pt')
#       2 files.download('/content/yolov5/runs/train/pcb_1st/weights/last.pt')
#       3 # files.download('/content/yolov5/dataset.yaml')
#       4 files.download('/content/yolov5/runs/train/pcb_1st/hyp.yaml')
#
# NameError: name 'files' is not defined

# %%
files.download('/content/yolov5/dataset.yaml')
files.download('/content/yolov5/models/yolov5s.yaml')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files

# %%
pip install pyinstaller
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.1/710.1 kB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.4/338.4 kB 28.0 MB/s eta 0:00:00
# ...

# %%
# !pyinstaller --onefile --noconsole main.py
# Out:
# 326 INFO: PyInstaller: 6.11.1, contrib hooks: 2024.10
# 326 INFO: Python: 3.10.12
# 328 INFO: Platform: Linux-6.1.85+-x86_64-with-glibc2.35
# 328 INFO: Python environment: /usr
# 708 INFO: wrote /content/drive/MyDrive/total folder/main.spec
# 719 INFO: Module search paths (PYTHONPATH):
# ['/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/setuptools/_vendor',
#  '/content/drive/MyDrive/total folder']
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 1626 INFO: checking Analysis
# 1627 INFO: Building Analysis because Analysis-00.toc is non existent
# 1627 INFO: Running Analysis Analysis-00.toc
# 1627 INFO: Target bytecode optimization level: 0
# 1627 INFO: Initializing module dependency graph...
# ...

# %%
import os

# %%
pip uninstall pathlib
# Out:
# Found existing installation: pathlib 1.0.1
# Uninstalling pathlib-1.0.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pathlib-1.0.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pathlib.py
# Proceed (Y/n)? y
# Y
#   Successfully uninstalled pathlib-1.0.1

# %%
os.chdir("/content/drive/MyDrive/total folder")
# %pwd
# Out:
# '/content/drive/MyDrive/total folder'

# %%
pip uninstall pathlib
# Out:
# Found existing installation: pathlib 1.0.1
# Uninstalling pathlib-1.0.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pathlib-1.0.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pathlib.py
# Proceed (Y/n)? Y
# Y
#   Successfully uninstalled pathlib-1.0.1
